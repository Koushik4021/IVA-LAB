# %%
import ffmpeg
input_video_path = 'C:/Users/91924/Desktop/MY WORKS/sem 7/image and video analytics/Walt Disney Animation Studios-Steamboat Willie Intro.mp4'

try:
    probe = ffmpeg.probe(input_video_path)

    # Extract video stream information
    video_stream = next((stream for stream in probe['streams'] if stream['codec_type'] == 'video'), None)

    if video_stream:
        width = video_stream['width']
        height = video_stream['height']
        frame_rate = eval(video_stream['r_frame_rate'])
        duration = float(video_stream['duration'])
        num_frames = int(video_stream['nb_frames'])

        print(f"Frame Width: {width}")
        print(f"Frame Height: {height}")
        print(f"Frame Rate: {frame_rate} frames per second")
        print(f"Duration: {duration} seconds")
        print(f"Number of Frames: {num_frames}")
    else:
        print("No video stream found in the file.")

except FileNotFoundError as e:
    print(f"Error: {e}")
    print("Please ensure ffmpeg is installed and added to the system PATH.")
# Out:
# Frame Width: 640
# Frame Height: 270
# Frame Rate: 30.0 frames per second
# Duration: 15.366667 seconds
# Number of Frames: 461

# %%
import subprocess
import matplotlib.pyplot as plt

def extract_frame_types(video_path):
    command = [
        'ffmpeg',
        '-i', video_path,
        '-vf', 'showinfo',
        '-f', 'null',
        '-'
    ]
    result = subprocess.run(command, stderr=subprocess.PIPE, text=True)
    output = result.stderr

    frame_types = {'I': 0, 'P': 0, 'B': 0}
    for line in output.split('\n'):
        if 'type:' in line:
            print(line)  # Debugging: Print the line containing 'type:'
            if 'type:I' in line:
                frame_types['I'] += 1
            elif 'type:P' in line:
                frame_types['P'] += 1
            elif 'type:B' in line:
                frame_types['B'] += 1
    
    return frame_types

video_path = 'C:/Users/91924/Desktop/MY WORKS/sem 7/image and video analytics/Walt Disney Animation Studios-Steamboat Willie Intro.mp4'
frame_types = extract_frame_types(video_path)
total_frames = sum(frame_types.values())
if total_frames == 0:
    print('No frames were detected.')
else:
    frame_percentages = {k: (v / total_frames) * 100 for k, v in frame_types.items()}

    # Printing percentages
    print('Frame percentages:', frame_percentages)

    # Plotting the distribution as a pie chart
    labels = list(frame_percentages.keys())
    sizes = list(frame_percentages.values())
    plt.figure(figsize=(10, 5))

    # Pie chart
    plt.subplot(1, 2, 1)
    plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
    plt.title('Frame Type Distribution')

    # Histogram
    plt.subplot(1, 2, 2)
    plt.bar(labels, sizes, color=['red', 'green', 'blue'])
    plt.xlabel('Frame Types')
    plt.ylabel('Percentage')
    plt.title('Frame Type Histogram')

    plt.tight_layout()
    plt.show()
# Out:
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:   0 pts:      0 pts_time:0       duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:1 type:I checksum:F257E677 plane_checksum:[1DB61D8E EB7AC0FD B11F07EC] mean:[19 127 129] stdev:[0.6 0.2 0.2]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:   1 pts:    512 pts_time:0.0333333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:1 type:I checksum:0EE5AD1B plane_checksum:[177AA7C0 D5C86949 9B749C03] mean:[24 127 130] stdev:[1.3 0.6 0.4]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:   2 pts:   1024 pts_time:0.0666667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:0EE5AD1B plane_checksum:[177AA7C0 D5C86949 9B749C03] mean:[24 127 130] stdev:[1.3 0.6 0.4]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:   3 pts:   1536 pts_time:0.1     duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:1 type:I checksum:C58C5163 plane_checksum:[FB102D8D DA50C47D 0A9B5F4A] mean:[32 124 131] stdev:[2.2 0.6 0.0]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:   4 pts:   2048 pts_time:0.133333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:1 type:I checksum:4945305D plane_checksum:[D9FC2C36 F6245E4B 48BFA5CD] mean:[45 120 133] stdev:[3.1 0.8 0.4]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:   5 pts:   2560 pts_time:0.166667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:1 type:I checksum:2F3AE7F8 plane_checksum:[44DEBF55 CD2DC410 A6036484] mean:[60 118 134] stdev:[4.3 0.5 0.9]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:   6 pts:   3072 pts_time:0.2     duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:1 type:I checksum:7018610A plane_checksum:[81EE24B1 3FA30779 329734E0] mean:[75 115 135] stdev:[5.5 0.9 1.0]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:   7 pts:   3584 pts_time:0.233333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:7018610A plane_checksum:[81EE24B1 3FA30779 329734E0] mean:[75 115 135] stdev:[5.5 0.9 1.0]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:   8 pts:   4096 pts_time:0.266667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:1 type:I checksum:65BE9F59 plane_checksum:[F22B9907 C3AFEE99 8FF117AA] mean:[91 112 137] stdev:[6.7 0.4 0.9]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:   9 pts:   4608 pts_time:0.3     duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:1 type:I checksum:C17B82B2 plane_checksum:[B7114178 58BA4FC0 09FAF16B] mean:[107 110 138] stdev:[7.8 1.0 1.2]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  10 pts:   5120 pts_time:0.333333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:1 type:I checksum:22B41C1F plane_checksum:[E9AF2378 68C2D1CD 61EE26CB] mean:[124 107 140] stdev:[8.9 1.3 1.3]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  11 pts:   5632 pts_time:0.366667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:1 type:I checksum:20EE477E plane_checksum:[AE4EB99C 83729821 CC6FF5A3] mean:[140 104 141] stdev:[10.2 1.5 1.5]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  12 pts:   6144 pts_time:0.4     duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:20EE477E plane_checksum:[AE4EB99C 83729821 CC6FF5A3] mean:[140 104 141] stdev:[10.2 1.5 1.5]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  13 pts:   6656 pts_time:0.433333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:1 type:I checksum:F2519EE4 plane_checksum:[3376156C E20EAA48 C8F3DF21] mean:[156 101 142] stdev:[11.2 0.9 1.5]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  14 pts:   7168 pts_time:0.466667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:1 type:I checksum:16F82FB6 plane_checksum:[02B1F128 A7046088 2E7ADDE8] mean:[169 99 144] stdev:[12.4 1.8 1.5]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  15 pts:   7680 pts_time:0.5     duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:1 type:I checksum:22430914 plane_checksum:[0B5FC99C 94999ED5 B9D0A085] mean:[183 96 145] stdev:[13.3 2.3 1.5]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  16 pts:   8192 pts_time:0.533333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:1 type:I checksum:F3EA5C06 plane_checksum:[B441DDBF AE5832A6 3F3F4B92] mean:[193 94 146] stdev:[14.1 1.9 1.6]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  17 pts:   8704 pts_time:0.566667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:F3EA5C06 plane_checksum:[B441DDBF AE5832A6 3F3F4B92] mean:[193 94 146] stdev:[14.1 1.9 1.6]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  18 pts:   9216 pts_time:0.6     duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:1 type:I checksum:55EE4F06 plane_checksum:[50537EEA 05C89AA4 1E143569] mean:[200 93 146] stdev:[14.0 1.8 2.9]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  19 pts:   9728 pts_time:0.633333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:CD2FCDAA plane_checksum:[F7EEBAAA D76BE8E7 2DEC2A0A] mean:[205 92 144] stdev:[14.0 1.9 4.4]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  20 pts:  10240 pts_time:0.666667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:B checksum:9E510C7B plane_checksum:[070EEAEB 2480F633 DA6E2B3F] mean:[206 92 144] stdev:[13.9 1.9 4.4]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  21 pts:  10752 pts_time:0.7     duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:B checksum:173115C7 plane_checksum:[7200FDF8 140DF4C4 D5DD22ED] mean:[206 92 144] stdev:[13.9 1.9 4.4]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  22 pts:  11264 pts_time:0.733333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:B checksum:BA6E247E plane_checksum:[74E917C3 FDCFF251 9BE11A5B] mean:[206 92 144] stdev:[14.0 1.9 4.4]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  23 pts:  11776 pts_time:0.766667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:B checksum:98170FCB plane_checksum:[E981EF81 2480F633 D5FE29F9] mean:[206 92 144] stdev:[13.9 1.9 4.4]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  24 pts:  12288 pts_time:0.8     duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:B checksum:7E4E27AC plane_checksum:[7E0A1D45 235DF1DB AE37187D] mean:[206 92 144] stdev:[14.0 1.9 4.4]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  25 pts:  12800 pts_time:0.833333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:31A23F9C plane_checksum:[9FC745AB 2709ED14 00910CCE] mean:[206 92 144] stdev:[14.0 1.9 4.4]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  26 pts:  13312 pts_time:0.866667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:599736FB plane_checksum:[30DF3AF0 187AED4B BF5B0EB1] mean:[206 92 144] stdev:[14.0 1.9 4.5]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  27 pts:  13824 pts_time:0.9     duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:599736FB plane_checksum:[30DF3AF0 187AED4B BF5B0EB1] mean:[206 92 144] stdev:[14.0 1.9 4.5]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  28 pts:  14336 pts_time:0.933333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:8A103027 plane_checksum:[590A32D3 AEFCED57 23AC0FEE] mean:[206 92 144] stdev:[14.0 1.9 4.5]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  29 pts:  14848 pts_time:0.966667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:E3A10770 plane_checksum:[C08302C0 0E4AEE20 F3561681] mean:[206 92 144] stdev:[14.1 1.9 4.6]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  30 pts:  15360 pts_time:1       duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:C4D3C51A plane_checksum:[8288B53E 1B3EEF4B FA332082] mean:[206 92 144] stdev:[14.3 1.9 4.7]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  31 pts:  15872 pts_time:1.033333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:129059B0 plane_checksum:[734A31D2 7A05F39C 72733433] mean:[206 92 144] stdev:[14.6 2.0 5.1]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  32 pts:  16384 pts_time:1.066667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:1B655C71 plane_checksum:[E17234B8 A091F3B8 FE1A33F2] mean:[206 92 144] stdev:[14.6 2.0 5.1]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  33 pts:  16896 pts_time:1.1     duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:75DBD32A plane_checksum:[27ED8C45 8883F92E 447E4DA8] mean:[205 92 145] stdev:[15.0 2.0 5.5]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  34 pts:  17408 pts_time:1.133333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:9DEF02CB plane_checksum:[B7098E29 6D440075 4BE6741E] mean:[205 93 145] stdev:[15.3 2.0 5.9]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  35 pts:  17920 pts_time:1.166667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:2A1F30EC plane_checksum:[1D2E83BC 63DA069B 33C9A686] mean:[204 93 145] stdev:[16.0 2.1 6.3]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  36 pts:  18432 pts_time:1.2     duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:6D1A5858 plane_checksum:[465A59B4 3A47115E CDD7ED37] mean:[202 93 145] stdev:[17.6 2.1 6.7]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  37 pts:  18944 pts_time:1.233333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:855C58A5 plane_checksum:[DDF359EA 94591162 1C18ED4A] mean:[202 93 145] stdev:[17.6 2.1 6.7]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  38 pts:  19456 pts_time:1.266667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:BB022675 plane_checksum:[B0DD6B3C 95D3397C DBA281AE] mean:[199 93 146] stdev:[21.1 2.2 6.8]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  39 pts:  19968 pts_time:1.3     duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:82FBE855 plane_checksum:[DB0CC7EE 082684A0 507F9BB8] mean:[194 93 147] stdev:[29.1 2.7 6.7]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  40 pts:  20480 pts_time:1.333333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:E472AFA6 plane_checksum:[FDD81513 FEC7EE8C BA27ABF8] mean:[189 94 147] stdev:[36.0 3.1 6.8]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  41 pts:  20992 pts_time:1.366667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:F4F69CE0 plane_checksum:[6FD0F21B A5EC054F 8A1CA567] mean:[185 94 147] stdev:[38.6 3.2 6.7]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  42 pts:  21504 pts_time:1.4     duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:0E1B9E0E plane_checksum:[5478F2BF 9DCF05D0 7644A570] mean:[185 94 147] stdev:[38.6 3.2 6.7]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  43 pts:  22016 pts_time:1.433333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:ACD7025E plane_checksum:[4B57F408 49EF31A9 9EBBDC8F] mean:[181 94 147] stdev:[38.6 3.1 6.6]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  44 pts:  22528 pts_time:1.466667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:9D797D7C plane_checksum:[46AD42B8 C13C3319 25BC07AB] mean:[178 94 147] stdev:[38.0 3.3 6.4]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  45 pts:  23040 pts_time:1.5     duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:B64E5372 plane_checksum:[E21ACC15 008D3EB2 1DDB489C] mean:[175 94 148] stdev:[37.6 3.3 6.3]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  46 pts:  23552 pts_time:1.533333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:ED7BC896 plane_checksum:[9EED06E2 275811BF 554DAFF5] mean:[170 94 148] stdev:[37.6 3.5 5.5]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  47 pts:  24064 pts_time:1.566667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:EF9FC323 plane_checksum:[781BFFD9 E48211C4 961AB177] mean:[170 94 148] stdev:[37.6 3.5 5.5]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  48 pts:  24576 pts_time:1.6     duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:1DE0FD3B plane_checksum:[A8858730 C08E0E47 A03D67C4] mean:[159 94 149] stdev:[36.4 3.8 3.9]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  49 pts:  25088 pts_time:1.633333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:C5EB81AB plane_checksum:[245C718E 641E49E9 909AC625] mean:[167 93 150] stdev:[25.8 2.4 4.0]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  50 pts:  25600 pts_time:1.666667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:01A14521 plane_checksum:[F5ECCBE3 0F7DBC63 ED5BBCBD] mean:[185 92 150] stdev:[20.8 2.6 4.9]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  51 pts:  26112 pts_time:1.7     duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:999E999B plane_checksum:[574C4B1D 5C2D7973 1D85D4FC] mean:[191 93 147] stdev:[31.9 3.0 6.4]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  52 pts:  26624 pts_time:1.733333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:6033C589 plane_checksum:[71396E33 66657FDA E453D76D] mean:[191 93 147] stdev:[32.0 2.9 6.4]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  53 pts:  27136 pts_time:1.766667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:876E75A3 plane_checksum:[436DA2FA C9B0EA22 568AE869] mean:[186 94 147] stdev:[37.5 3.2 6.4]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  54 pts:  27648 pts_time:1.8     duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:1DC15D72 plane_checksum:[CC2D1E5E 6A9E2A5D 308114B7] mean:[181 94 147] stdev:[39.6 3.2 6.2]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  55 pts:  28160 pts_time:1.833333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:92684275 plane_checksum:[68C18F4D 58A9541D 5D5B5EFC] mean:[176 95 148] stdev:[39.6 3.1 6.0]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  56 pts:  28672 pts_time:1.866667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:9297A5B6 plane_checksum:[315CA91F D9D05863 6B46A425] mean:[172 95 148] stdev:[39.0 3.1 6.0]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  57 pts:  29184 pts_time:1.9     duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:7826A3B1 plane_checksum:[F5CCA69C 8786588E 6AECA478] mean:[172 95 148] stdev:[39.0 3.1 6.0]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  58 pts:  29696 pts_time:1.933333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:905E4EC2 plane_checksum:[CBC8EB65 DC5A6023 4788032B] mean:[168 95 149] stdev:[38.5 3.1 6.0]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  59 pts:  30208 pts_time:1.966667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:16BE4CA9 plane_checksum:[E95C90C6 4C7B4E95 E7416D3F] mean:[163 95 149] stdev:[38.4 3.3 5.8]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  60 pts:  30720 pts_time:2       duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:01711BA5 plane_checksum:[60D1CC73 A724966E BEA6B8A6] mean:[153 95 150] stdev:[39.2 3.6 5.2]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  61 pts:  31232 pts_time:2.033333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:A1BDBEF5 plane_checksum:[3CA3209A C0A0A336 F1E5FB16] mean:[147 95 150] stdev:[37.1 3.7 3.9]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  62 pts:  31744 pts_time:2.066667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:AECEC351 plane_checksum:[627B22AB AEA7A4FB AB7BFB9C] mean:[147 95 150] stdev:[37.1 3.7 3.9]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  63 pts:  32256 pts_time:2.1     duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:0DB5C410 plane_checksum:[D7567156 47703C8C AC40162E] mean:[151 94 150] stdev:[31.8 2.8 4.8]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  64 pts:  32768 pts_time:2.133333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:4B00A34D plane_checksum:[F2229DC6 CDD41012 54C1F566] mean:[163 94 150] stdev:[33.3 3.0 5.7]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  65 pts:  33280 pts_time:2.166667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:789CEDF3 plane_checksum:[7B818AF3 6D4C3351 D6902FAF] mean:[171 94 149] stdev:[38.9 3.0 5.8]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  66 pts:  33792 pts_time:2.2     duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:066BAF7A plane_checksum:[177A28EE FA0548FB C0353D91] mean:[167 94 149] stdev:[38.1 3.0 5.7]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  67 pts:  34304 pts_time:2.233333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:C27CA054 plane_checksum:[5A1518F9 114C48F0 1E503E6B] mean:[167 94 149] stdev:[38.1 3.0 5.7]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  68 pts:  34816 pts_time:2.266667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:6BEEB5EE plane_checksum:[7CA9064F 4AC04AF4 C4E364AB] mean:[165 94 149] stdev:[36.8 3.3 5.6]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  69 pts:  35328 pts_time:2.3     duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:4BBF5AC8 plane_checksum:[964E5A95 F6355E77 B869A1AD] mean:[162 95 150] stdev:[36.7 3.4 5.5]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  70 pts:  35840 pts_time:2.333333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:A5293DB6 plane_checksum:[E9560836 79464DAA 9F77E7C7] mean:[157 94 150] stdev:[37.2 3.7 5.2]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  71 pts:  36352 pts_time:2.366667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:5E2B37D7 plane_checksum:[9633A56A 5FDE64CA 54DF2D94] mean:[150 95 150] stdev:[36.7 3.9 4.7]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  72 pts:  36864 pts_time:2.4     duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:2A9D40A8 plane_checksum:[9F6BAA79 B98A6598 41613088] mean:[150 95 150] stdev:[36.7 3.9 4.7]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  73 pts:  37376 pts_time:2.433333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:65923387 plane_checksum:[9031978F 8BBF5744 1B3744A5] mean:[148 95 151] stdev:[34.2 3.6 4.0]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  74 pts:  37888 pts_time:2.466667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:5BA76C6F plane_checksum:[6CEBF475 44D93DEA 23313A01] mean:[149 94 150] stdev:[31.2 3.3 4.6]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  75 pts:  38400 pts_time:2.5     duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:FAF383A7 plane_checksum:[C322282D D89341EF 19B2198B] mean:[158 94 150] stdev:[33.9 3.2 5.3]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  76 pts:  38912 pts_time:2.533333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:5127CFC1 plane_checksum:[AABB0F82 5F8A59A3 8850669C] mean:[166 95 149] stdev:[39.6 3.2 5.4]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  77 pts:  39424 pts_time:2.566667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:0D78DE9A plane_checksum:[5F3E1D67 B2A25A72 477166C1] mean:[166 95 149] stdev:[39.6 3.2 5.4]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  78 pts:  39936 pts_time:2.6     duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:704B5C40 plane_checksum:[4C7582CF AEF16094 28D178CE] mean:[162 95 149] stdev:[37.8 3.2 5.4]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  79 pts:  40448 pts_time:2.633333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:FE1497F1 plane_checksum:[A8F8754D D5E66074 3A8DC221] mean:[159 95 150] stdev:[36.5 3.3 5.4]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  80 pts:  40960 pts_time:2.666667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:8C7E6F4E plane_checksum:[0A0805E7 445E60B8 B84608AF] mean:[155 95 150] stdev:[36.1 3.5 5.2]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  81 pts:  41472 pts_time:2.7     duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:0F1C9F8F plane_checksum:[DF44FABF BB174F6D 1B275554] mean:[151 95 151] stdev:[35.1 3.7 4.7]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  82 pts:  41984 pts_time:2.733333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:4F89AB55 plane_checksum:[AB19FF0D E8D84E9A 56405D9F] mean:[151 95 151] stdev:[35.1 3.7 4.8]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  83 pts:  42496 pts_time:2.766667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:7ED28F58 plane_checksum:[58EFDE87 A6501E82 F4329240] mean:[152 94 151] stdev:[32.6 3.3 4.7]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  84 pts:  43008 pts_time:2.8     duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:A3EBD1FF plane_checksum:[64A660A1 245606EB B56B6A73] mean:[152 94 151] stdev:[31.7 3.2 5.0]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  85 pts:  43520 pts_time:2.833333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:BC045B02 plane_checksum:[BCBDE11A 88D92EE0 534C4AF9] mean:[159 94 151] stdev:[35.1 3.4 5.6]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  86 pts:  44032 pts_time:2.866667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:A2E57F0D plane_checksum:[DF7D91E5 8D3B6155 FE6E8BC4] mean:[163 95 149] stdev:[40.0 3.3 5.5]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  87 pts:  44544 pts_time:2.9     duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:8C547F9F plane_checksum:[F03391E2 FD4D6140 34638C6E] mean:[163 95 149] stdev:[40.0 3.3 5.6]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  88 pts:  45056 pts_time:2.933333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:08CA965F plane_checksum:[C8186D00 0EE36C08 D347BD48] mean:[160 95 150] stdev:[38.1 3.3 5.5]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  89 pts:  45568 pts_time:2.966667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:5402652E plane_checksum:[A414E53F 290E842A 7741FBA7] mean:[155 95 150] stdev:[37.7 3.5 5.3]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  90 pts:  46080 pts_time:3       duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:455A3117 plane_checksum:[DA34579E 20869192 1B5547D8] mean:[150 95 151] stdev:[37.0 3.7 4.9]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  91 pts:  46592 pts_time:3.033333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:778063F2 plane_checksum:[FF0E6658 A98563D2 59C499B9] mean:[148 95 151] stdev:[34.4 3.3 4.9]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  92 pts:  47104 pts_time:3.066667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:80856A46 plane_checksum:[D2B969A9 6C1F642C EA6F9C62] mean:[148 95 151] stdev:[34.4 3.3 4.9]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  93 pts:  47616 pts_time:3.1     duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:8B559855 plane_checksum:[F550AA55 1E8A6021 C74A8DD0] mean:[147 95 151] stdev:[31.7 2.9 5.2]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  94 pts:  48128 pts_time:3.133333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:035A86C8 plane_checksum:[A715D856 F8A152DB 3BBD5B88] mean:[155 95 151] stdev:[34.0 3.2 5.8]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  95 pts:  48640 pts_time:3.166667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:639BFE34 plane_checksum:[CDCC96AE B7B470A9 13A6F6CE] mean:[159 95 150] stdev:[38.3 3.1 5.8]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  96 pts:  49152 pts_time:3.2     duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:5E3549AF plane_checksum:[A62A8F32 955B64A9 5CF355C5] mean:[152 95 151] stdev:[35.1 3.4 5.4]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  97 pts:  49664 pts_time:3.233333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:9DFE5394 plane_checksum:[E6C498E2 203A64BD 59E655E6] mean:[152 95 151] stdev:[35.1 3.4 5.4]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  98 pts:  50176 pts_time:3.266667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:3EAF6561 plane_checksum:[D5392AE4 65B0E707 53395367] mean:[156 94 151] stdev:[29.8 3.0 4.4]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n:  99 pts:  50688 pts_time:3.3     duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:DFEE1EFC plane_checksum:[905CBBC4 8DC8133A 20214FEF] mean:[167 93 151] stdev:[21.3 1.8 4.7]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 100 pts:  51200 pts_time:3.333333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:F8ACC5F9 plane_checksum:[D1DFED57 883A0081 07C1D812] mean:[176 93 150] stdev:[23.3 2.2 4.1]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 101 pts:  51712 pts_time:3.366667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:916992FC plane_checksum:[B4BB9B16 F883A871 68DD4F66] mean:[170 94 149] stdev:[38.0 3.5 3.9]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 102 pts:  52224 pts_time:3.4     duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:3C2DB09C plane_checksum:[3D33B80D 8F10A7EC C6165094] mean:[171 94 149] stdev:[38.0 3.6 3.9]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 103 pts:  52736 pts_time:3.433333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:DE0C3CD6 plane_checksum:[2C6A1846 F53624C3 9D6CFFBE] mean:[163 94 149] stdev:[40.2 3.3 4.0]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 104 pts:  53248 pts_time:3.466667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:BD422529 plane_checksum:[40C653C2 5ED6410A 872B904E] mean:[155 94 149] stdev:[35.7 3.4 3.9]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 105 pts:  53760 pts_time:3.5     duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:175CCCC5 plane_checksum:[4AB0F89F ACACC683 C62D0D94] mean:[159 94 150] stdev:[30.1 2.9 4.1]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 106 pts:  54272 pts_time:3.533333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:A40CDAB2 plane_checksum:[5FDE94D1 E9F1F72A D5224EA8] mean:[171 92 151] stdev:[19.9 1.7 4.1]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 107 pts:  54784 pts_time:3.566667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:1B7222C2 plane_checksum:[A386DC20 D269F98D 1D934CF7] mean:[171 92 151] stdev:[20.0 1.8 4.2]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 108 pts:  55296 pts_time:3.6     duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:ADA16980 plane_checksum:[E8D32A3A F18D197D F71025C9] mean:[175 93 150] stdev:[30.4 2.9 4.4]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 109 pts:  55808 pts_time:3.633333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:8CA1065C plane_checksum:[089BC2F9 5FCF069B E08D3CB9] mean:[166 94 149] stdev:[40.5 3.0 4.5]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 110 pts:  56320 pts_time:3.666667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:8F9DACF4 plane_checksum:[92B8DCE2 BFB0E933 D87DE6C1] mean:[156 94 150] stdev:[34.4 3.3 4.2]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 111 pts:  56832 pts_time:3.7     duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:1 type:I checksum:F58DD5EE plane_checksum:[229A2D01 AEE9068E 7D05A25F] mean:[162 93 151] stdev:[25.7 2.6 4.6]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 112 pts:  57344 pts_time:3.733333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:F58DD5EE plane_checksum:[229A2D01 AEE9068E 7D05A25F] mean:[162 93 151] stdev:[25.7 2.6 4.6]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 113 pts:  57856 pts_time:3.766667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:926A2883 plane_checksum:[7A41CF40 A66580B0 9199D875] mean:[174 92 151] stdev:[21.0 2.2 4.7]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 114 pts:  58368 pts_time:3.8     duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:8A2DA567 plane_checksum:[79C05408 5354B668 98ED9AE8] mean:[176 92 151] stdev:[32.0 3.0 4.4]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 115 pts:  58880 pts_time:3.833333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:81F66E3A plane_checksum:[6BC89385 2441D883 FCE60223] mean:[172 92 150] stdev:[33.2 2.3 4.9]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 116 pts:  59392 pts_time:3.866667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:46BFD90E plane_checksum:[D32572E2 9AFD17B9 E7C14E73] mean:[165 91 152] stdev:[25.4 2.0 4.8]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 117 pts:  59904 pts_time:3.9     duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:6EDEBFCC plane_checksum:[8CE05568 0BB0177D 12EA52E7] mean:[165 91 152] stdev:[25.4 2.0 4.8]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 118 pts:  60416 pts_time:3.933333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:9162D902 plane_checksum:[8304AB65 3DAB3DAF 6DB2EFDF] mean:[175 90 153] stdev:[18.3 1.8 4.6]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 119 pts:  60928 pts_time:3.966667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:8C347010 plane_checksum:[22681CF4 CD5969BE 9D6AE94F] mean:[184 90 152] stdev:[26.7 2.0 4.5]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 120 pts:  61440 pts_time:4       duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:5212A6FF plane_checksum:[146A06DF 7AAAA853 0599F7BE] mean:[180 90 150] stdev:[31.3 2.5 6.9]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 121 pts:  61952 pts_time:4.033333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:3571D8D6 plane_checksum:[7DD43996 1AD4A962 0407F5CF] mean:[180 90 150] stdev:[31.4 2.5 6.9]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 122 pts:  62464 pts_time:4.066667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:8DEF3A1A plane_checksum:[5EE9C474 3A9F11F3 38CB63A4] mean:[171 88 154] stdev:[23.8 2.8 5.9]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 123 pts:  62976 pts_time:4.1     duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:A6C64E42 plane_checksum:[BD99F1C7 34B73510 D2C6275C] mean:[176 87 155] stdev:[19.2 2.7 4.0]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 124 pts:  63488 pts_time:4.133333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:9C696FCF plane_checksum:[83CE3CD3 658F587D 0289DA70] mean:[184 87 153] stdev:[23.7 2.6 5.7]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 125 pts:  64000 pts_time:4.166667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:F8A2D48C plane_checksum:[4143E891 42EE3618 E9C9B5D4] mean:[183 87 153] stdev:[24.5 2.9 7.2]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 126 pts:  64512 pts_time:4.2     duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:A571D885 plane_checksum:[485AE95E C34C35E8 61A2B930] mean:[183 87 153] stdev:[24.5 2.9 7.2]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 127 pts:  65024 pts_time:4.233333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:5E73F85F plane_checksum:[6992787C 7C578CB3 4190F321] mean:[179 86 155] stdev:[22.2 2.8 6.1]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 128 pts:  65536 pts_time:4.266667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:81561F56 plane_checksum:[C82AFB0F 3C98D41F 2F00500A] mean:[176 85 157] stdev:[17.6 2.4 3.5]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 129 pts:  66048 pts_time:4.3     duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:5FE6B8A0 plane_checksum:[619A0FDD 8DA49AEB F6E90DD8] mean:[180 84 156] stdev:[17.1 2.4 3.5]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 130 pts:  66560 pts_time:4.333333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:675DB28D plane_checksum:[33F48005 780DDDAC 8E4554CD] mean:[188 85 154] stdev:[19.2 2.3 4.3]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 131 pts:  67072 pts_time:4.366667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:3D9CE9C5 plane_checksum:[102DBA98 DC17DE69 341B50B5] mean:[188 85 154] stdev:[19.2 2.3 4.3]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 132 pts:  67584 pts_time:4.4     duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:72AE1522 plane_checksum:[9AA6438F 7F801530 E418BC54] mean:[188 85 153] stdev:[22.1 2.1 6.8]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 133 pts:  68096 pts_time:4.433333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:80446E27 plane_checksum:[F2E1792B DBEECAB5 7FA52A38] mean:[184 85 155] stdev:[19.6 2.3 5.9]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 134 pts:  68608 pts_time:4.466667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:4263D272 plane_checksum:[B25749B6 8C7DC15D 5A61C750] mean:[187 85 154] stdev:[18.4 1.9 4.3]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 135 pts:  69120 pts_time:4.5     duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:1F02FFE6 plane_checksum:[320D49EF 893EEDCB 56BFC81D] mean:[191 85 153] stdev:[18.4 2.0 6.1]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 136 pts:  69632 pts_time:4.533333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:C0F40AA3 plane_checksum:[02B853E9 FAA5ED22 4797C97A] mean:[191 85 153] stdev:[18.4 2.1 6.0]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 137 pts:  70144 pts_time:4.566667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:5B011110 plane_checksum:[080513B1 D4A13F9D EC65BDB3] mean:[185 84 156] stdev:[17.8 2.0 4.4]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 138 pts:  70656 pts_time:4.6     duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:0DAC8367 plane_checksum:[E62EFE92 1EA944C9 BB523FFD] mean:[187 84 155] stdev:[16.6 1.9 4.1]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 139 pts:  71168 pts_time:4.633333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:2EB8C810 plane_checksum:[0500F224 33BEE424 3F23F1AA] mean:[199 85 150] stdev:[16.3 1.9 5.5]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 140 pts:  71680 pts_time:4.666667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:DACDC76F plane_checksum:[4DD8049D CBB1AF3B 81331397] mean:[191 84 152] stdev:[21.2 2.1 6.0]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 141 pts:  72192 pts_time:4.7     duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:3F08D6B1 plane_checksum:[A3851261 2D50AF96 381514BA] mean:[191 84 152] stdev:[21.2 2.1 6.0]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 142 pts:  72704 pts_time:4.733333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:69C06440 plane_checksum:[7EC59F92 0B1167A9 E89F5CF6] mean:[189 84 154] stdev:[17.6 2.0 5.7]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 143 pts:  73216 pts_time:4.766667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:297870FD plane_checksum:[EAE1BA57 5A5968CA 97FF4DCD] mean:[203 86 148] stdev:[15.7 1.8 5.4]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 144 pts:  73728 pts_time:4.8     duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:B7971DBA plane_checksum:[82BACCA3 883F0C89 2DAB447F] mean:[194 85 151] stdev:[22.2 2.3 7.5]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 145 pts:  74240 pts_time:4.833333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:ACE44928 plane_checksum:[8893F848 5AAF7E95 12FED22D] mean:[192 84 153] stdev:[17.3 2.3 5.0]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 146 pts:  74752 pts_time:4.866667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:235846A9 plane_checksum:[A0BCF694 C61C7EA7 174AD150] mean:[192 84 153] stdev:[17.3 2.3 5.0]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 147 pts:  75264 pts_time:4.9     duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:B63B5FE4 plane_checksum:[84706287 C2478C2D C3FE7121] mean:[190 84 152] stdev:[21.6 2.3 6.4]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 148 pts:  75776 pts_time:4.933333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:8FE7B873 plane_checksum:[8DA0319C CFBF4354 FA494383] mean:[189 84 154] stdev:[18.8 2.2 6.1]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 149 pts:  76288 pts_time:4.966667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:B2A5815E plane_checksum:[74620F6C 9C6C2FF8 FA4F41FA] mean:[189 84 154] stdev:[18.8 2.3 4.6]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 150 pts:  76800 pts_time:5       duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:F77D1861 plane_checksum:[C487E737 245045D7 02C7EB35] mean:[186 84 155] stdev:[18.9 2.5 5.0]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 151 pts:  77312 pts_time:5.033333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:3410129E plane_checksum:[D361E1CF 519045AC 6404EB05] mean:[186 84 155] stdev:[18.9 2.5 5.0]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 152 pts:  77824 pts_time:5.066667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:A0DFC974 plane_checksum:[EB825B7E A2185167 9A281C8F] mean:[184 84 155] stdev:[19.6 2.4 4.0]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 153 pts:  78336 pts_time:5.1     duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:236013F1 plane_checksum:[A27EE020 FE1191B4 F980A1FF] mean:[187 84 154] stdev:[19.0 2.5 4.9]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 154 pts:  78848 pts_time:5.133333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:53B16B0D plane_checksum:[DB66E941 CF754687 3ABD3B36] mean:[185 84 155] stdev:[19.7 2.6 3.6]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 155 pts:  79360 pts_time:5.166667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:C449DF4B plane_checksum:[2C61D8F7 7730871C CD687F29] mean:[187 84 154] stdev:[20.3 2.8 4.8]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 156 pts:  79872 pts_time:5.2     duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:12FDDE7E plane_checksum:[B902D65F 295086FE 3C4C8112] mean:[187 84 154] stdev:[20.3 2.8 4.8]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 157 pts:  80384 pts_time:5.233333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:41444454 plane_checksum:[98858157 E4E563C2 96D05F2C] mean:[183 84 155] stdev:[20.5 3.0 3.3]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 158 pts:  80896 pts_time:5.266667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:2D541B50 plane_checksum:[53891879 CB12A030 D0CE6298] mean:[187 84 154] stdev:[21.7 3.5 4.3]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 159 pts:  81408 pts_time:5.3     duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:E80EE344 plane_checksum:[8DA6E994 40210661 C03FF340] mean:[203 86 146] stdev:[22.1 3.4 4.8]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 160 pts:  81920 pts_time:5.333333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:823E188B plane_checksum:[39EA9AD9 0AE6E231 A7429B63] mean:[195 86 148] stdev:[26.3 3.3 8.1]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 161 pts:  82432 pts_time:5.366667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:617A0DC0 plane_checksum:[206990AE CDB2E31C 657699D8] mean:[195 86 148] stdev:[26.3 3.3 8.1]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 162 pts:  82944 pts_time:5.4     duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:17834960 plane_checksum:[98AEC8E4 F7F6CC26 7BA3B438] mean:[191 86 151] stdev:[22.5 3.6 6.7]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 163 pts:  83456 pts_time:5.433333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:1CF350AE plane_checksum:[7267C0ED 5D3DA081 B58BEF22] mean:[186 86 153] stdev:[22.6 3.4 4.2]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 164 pts:  83968 pts_time:5.466667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:EF404ADE plane_checksum:[68B5C3C4 08B4B704 8298CFF8] mean:[188 86 153] stdev:[21.9 3.5 4.5]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 165 pts:  84480 pts_time:5.5     duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:391F58E4 plane_checksum:[FA60B1C8 62A29B74 3B1C0B99] mean:[186 86 153] stdev:[22.1 3.4 4.0]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 166 pts:  84992 pts_time:5.533333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:35741C6C plane_checksum:[6645BA48 7DECCEB3 86119353] mean:[189 86 153] stdev:[22.2 3.4 4.7]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 167 pts:  85504 pts_time:5.566667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:7C1C641A plane_checksum:[CE12153E 5E9B0A7A 1B1B4462] mean:[188 87 152] stdev:[23.2 3.7 3.9]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 168 pts:  86016 pts_time:5.6     duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:A0936C32 plane_checksum:[9ABB1D83 A1EF0A49 E31D4466] mean:[188 87 152] stdev:[23.2 3.7 4.0]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 169 pts:  86528 pts_time:5.633333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:F0C5C98D plane_checksum:[84F76785 3E689075 A1D7D184] mean:[189 87 151] stdev:[24.4 3.9 5.2]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 170 pts:  87040 pts_time:5.666667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:B checksum:4AC00F92 plane_checksum:[4D043C42 9E7F95C3 A0E23D7E] mean:[195 89 149] stdev:[23.3 3.6 4.2]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 171 pts:  87552 pts_time:5.7     duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:B checksum:6270DE1A plane_checksum:[AED7B6C5 D985C1B8 7D72658E] mean:[193 89 149] stdev:[24.9 3.6 5.5]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 172 pts:  88064 pts_time:5.733333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:B checksum:7A40D898 plane_checksum:[04872BDE AC8613FF 1B7B98BB] mean:[193 90 150] stdev:[24.4 3.5 4.7]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 173 pts:  88576 pts_time:5.766667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:5080D7E5 plane_checksum:[B9722B39 1D4314D2 41E597DA] mean:[193 90 150] stdev:[24.4 3.5 4.7]
# ...
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 404 pts: 206848 pts_time:13.466667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:B checksum:BCFA53BB plane_checksum:[AF9FE7C8 2EBE1BA5 B4CC503F] mean:[151 118 134] stdev:[66.1 2.4 2.9]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 405 pts: 207360 pts_time:13.5    duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:B checksum:DC7F98D9 plane_checksum:[10D6368E 42D0176A 15B94AE1] mean:[151 118 134] stdev:[66.2 2.4 2.9]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 406 pts: 207872 pts_time:13.533333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:AD5B274A plane_checksum:[4C03C707 021117E1 C7194853] mean:[152 118 134] stdev:[66.3 2.4 2.9]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 407 pts: 208384 pts_time:13.566667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:B checksum:0C4824C7 plane_checksum:[89FAC314 2A0318B4 CC4448F0] mean:[152 118 134] stdev:[66.3 2.4 2.9]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 408 pts: 208896 pts_time:13.6    duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:B41BE401 plane_checksum:[9C8C83B3 F1721712 7ADF493C] mean:[151 118 134] stdev:[66.2 2.4 2.9]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 409 pts: 209408 pts_time:13.633333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:B checksum:AF31CD9C plane_checksum:[C70F6157 0B631C30 6A115015] mean:[151 118 134] stdev:[66.2 2.4 2.8]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 410 pts: 209920 pts_time:13.666667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:B checksum:6DDDE03A plane_checksum:[D8D4781A 11341BE2 A7E84C3E] mean:[151 118 134] stdev:[66.2 2.4 2.8]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 411 pts: 210432 pts_time:13.7    duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:94824B44 plane_checksum:[95E0E82E 0A5E191A 82FC49ED] mean:[150 118 134] stdev:[66.1 2.4 2.9]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 412 pts: 210944 pts_time:13.733333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:B checksum:000141CA plane_checksum:[1B9BDA15 3AAF1B40 A3034C66] mean:[150 118 134] stdev:[66.1 2.4 2.9]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 413 pts: 211456 pts_time:13.766667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:B checksum:034EB33D plane_checksum:[53174A93 EDCE1C26 0FE04C84] mean:[151 118 134] stdev:[66.2 2.4 2.9]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 414 pts: 211968 pts_time:13.8    duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:EC355B73 plane_checksum:[6E07F814 11331972 02E349DE] mean:[151 118 134] stdev:[66.1 2.4 2.9]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 415 pts: 212480 pts_time:13.833333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:B checksum:E98F7FB9 plane_checksum:[CEBF179D 938F1AED 74964D2F] mean:[151 118 134] stdev:[66.2 2.4 2.8]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 416 pts: 212992 pts_time:13.866667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:A43D2D2B plane_checksum:[BAE7C8D7 A1771907 FBE84B3E] mean:[150 118 134] stdev:[66.0 2.4 2.9]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 417 pts: 213504 pts_time:13.9    duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:B checksum:7B0C27A0 plane_checksum:[D16EBD4D 3C6C1B45 FFCE4EFF] mean:[150 118 134] stdev:[66.1 2.4 2.8]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 418 pts: 214016 pts_time:13.933333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:B checksum:94908F02 plane_checksum:[F6302171 77BD1E09 7FCB4F88] mean:[151 118 134] stdev:[66.2 2.4 2.9]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 419 pts: 214528 pts_time:13.966667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:B checksum:5768AABF plane_checksum:[F9603959 72DC1F4D 6FF05219] mean:[150 118 134] stdev:[66.0 2.4 2.9]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 420 pts: 215040 pts_time:14      duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:B checksum:7EA58158 plane_checksum:[46991956 20541C3B 461E4BC7] mean:[150 118 134] stdev:[66.1 2.4 2.8]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 421 pts: 215552 pts_time:14.033333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:5F59D639 plane_checksum:[0DA975FB 42381957 757146E7] mean:[150 118 134] stdev:[66.3 2.4 2.8]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 422 pts: 216064 pts_time:14.066667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:B checksum:1533BF88 plane_checksum:[56BF5D10 9B2517EB 45AD4A8D] mean:[150 118 134] stdev:[66.3 2.4 2.9]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 423 pts: 216576 pts_time:14.1    duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:B checksum:764CE203 plane_checksum:[0332789E 98FF1A67 D0E24EFE] mean:[150 118 134] stdev:[66.2 2.4 2.9]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 424 pts: 217088 pts_time:14.133333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:B checksum:CCEE7EED plane_checksum:[DE23124A 71551C27 B8F5507C] mean:[150 118 134] stdev:[66.3 2.4 2.9]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 425 pts: 217600 pts_time:14.166667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:B checksum:5DAE3CC4 plane_checksum:[33E6D5ED CB0E18F9 C9FB4DCF] mean:[150 118 134] stdev:[66.4 2.4 2.9]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 426 pts: 218112 pts_time:14.2    duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:B checksum:DBD88FE6 plane_checksum:[05AD32BB 502A1525 1D374806] mean:[150 118 134] stdev:[66.3 2.4 2.9]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 427 pts: 218624 pts_time:14.233333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:200E8C03 plane_checksum:[C60A2F56 2709151F A975478E] mean:[150 118 134] stdev:[66.3 2.4 2.9]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 428 pts: 219136 pts_time:14.266667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:B checksum:3F1A8F53 plane_checksum:[59A128E4 B7BE195A 609F4D15] mean:[150 118 134] stdev:[66.2 2.4 2.9]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 429 pts: 219648 pts_time:14.3    duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:B checksum:AA2FDFA9 plane_checksum:[925C78D2 2AAD19A4 E3B14D33] mean:[149 118 134] stdev:[66.2 2.5 2.9]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 430 pts: 220160 pts_time:14.333333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:B checksum:A83B34DA plane_checksum:[43C7D345 B20E1792 815949F4] mean:[149 118 134] stdev:[66.2 2.5 2.9]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 431 pts: 220672 pts_time:14.366667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:B checksum:7D147999 plane_checksum:[9AD01929 516A1736 5396493A] mean:[149 118 134] stdev:[66.3 2.5 2.9]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 432 pts: 221184 pts_time:14.4    duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:F4607166 plane_checksum:[F23B144B 9DD81566 223C47B5] mean:[149 118 134] stdev:[66.3 2.5 2.9]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 433 pts: 221696 pts_time:14.433333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:B checksum:97BC0CD0 plane_checksum:[7074A646 44FC19C9 829F4CB2] mean:[149 118 134] stdev:[66.3 2.5 2.9]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 434 pts: 222208 pts_time:14.466667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:95E0CC53 plane_checksum:[D4425035 04B718C9 37036355] mean:[148 118 134] stdev:[65.8 2.4 2.8]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 435 pts: 222720 pts_time:14.5    duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:B checksum:DC70B5A7 plane_checksum:[3995F5F2 5E3224F4 74689AB2] mean:[145 119 134] stdev:[65.4 2.5 2.7]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 436 pts: 223232 pts_time:14.533333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:23AF974C plane_checksum:[88EDC5AC 818B198A DD19B807] mean:[140 118 135] stdev:[62.9 2.4 2.5]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 437 pts: 223744 pts_time:14.566667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:C0239299 plane_checksum:[7E91C13B 5A9B1971 77FCB7DE] mean:[140 118 135] stdev:[62.9 2.4 2.5]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 438 pts: 224256 pts_time:14.6    duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:B6EE8848 plane_checksum:[2F312FC1 C0377F0B BCB3D96D] mean:[134 119 135] stdev:[60.4 2.4 2.4]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 439 pts: 224768 pts_time:14.633333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:63348B36 plane_checksum:[F397A775 083485BB 88B85DF7] mean:[126 119 134] stdev:[57.3 2.3 2.4]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 440 pts: 225280 pts_time:14.666667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:D10DE1C5 plane_checksum:[60642DEB 139C716A 7F214270] mean:[115 120 134] stdev:[52.5 2.3 2.4]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 441 pts: 225792 pts_time:14.7    duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:4137FB79 plane_checksum:[B4400AE4 C709E7D2 B63508C3] mean:[104 121 134] stdev:[47.4 2.1 2.3]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 442 pts: 226304 pts_time:14.733333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:B754E489 plane_checksum:[AACBF366 7E0AE943 D9D207D1] mean:[104 121 134] stdev:[47.3 2.1 2.3]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 443 pts: 226816 pts_time:14.766667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:46A1DB94 plane_checksum:[3E3E66D1 04B69835 B75DDC7F] mean:[94 122 133] stdev:[42.3 1.9 2.3]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 444 pts: 227328 pts_time:14.8    duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:B95E5C53 plane_checksum:[05F63750 3EABD055 2289549F] mean:[83 123 132] stdev:[37.5 1.7 2.1]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 445 pts: 227840 pts_time:14.833333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:9E3CD73E plane_checksum:[6F4B2B11 4B5177E7 7F293446] mean:[72 124 132] stdev:[32.5 1.7 2.0]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 446 pts: 228352 pts_time:14.866667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:82A4F05E plane_checksum:[0E851DCD F3CC0F4B 27D5C346] mean:[61 124 132] stdev:[27.3 1.5 1.5]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 447 pts: 228864 pts_time:14.9    duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:899DFEC9 plane_checksum:[2EF52DB1 4A180E0B 6423C30D] mean:[61 124 132] stdev:[27.2 1.5 1.5]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 448 pts: 229376 pts_time:14.933333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:B300F06B plane_checksum:[073D2315 67F369D3 71896383] mean:[51 125 131] stdev:[21.8 1.1 1.2]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 449 pts: 229888 pts_time:14.966667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:1 type:I checksum:1AF4A349 plane_checksum:[41EAD0F7 51AFF9D6 4823D85E] mean:[41 126 130] stdev:[16.2 1.1 1.0]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 450 pts: 230400 pts_time:15      duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:4089AC5C plane_checksum:[30936267 0DE787C9 9F79C21D] mean:[33 127 130] stdev:[11.5 1.0 0.8]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 451 pts: 230912 pts_time:15.033333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:7F2FE2B9 plane_checksum:[CF7485CA B719E723 930575BD] mean:[25 127 130] stdev:[5.6 0.9 0.8]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 452 pts: 231424 pts_time:15.066667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:7F2FE2B9 plane_checksum:[CF7485CA B719E723 930575BD] mean:[25 127 130] stdev:[5.6 0.9 0.8]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 453 pts: 231936 pts_time:15.1    duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:1 type:I checksum:B73EC96F plane_checksum:[E779DBBF 6E0164EC A18588B5] mean:[20 128 128] stdev:[2.7 0.0 0.5]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 454 pts: 232448 pts_time:15.133333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:B checksum:1F4634C7 plane_checksum:[0BB44C78 6E0164EC 11E28354] mean:[18 128 128] stdev:[1.3 0.0 0.4]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 455 pts: 232960 pts_time:15.166667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:B checksum:09904C89 plane_checksum:[0B7C82A2 6E0164EC 6E0164EC] mean:[16 128 128] stdev:[0.6 0.0 0.0]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 456 pts: 233472 pts_time:15.2    duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:B checksum:DAC04489 plane_checksum:[7AEF7AA2 6E0164EC 6E0164EC] mean:[16 128 128] stdev:[0.6 0.0 0.0]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 457 pts: 233984 pts_time:15.233333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:B checksum:DAC04489 plane_checksum:[7AEF7AA2 6E0164EC 6E0164EC] mean:[16 128 128] stdev:[0.6 0.0 0.0]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 458 pts: 234496 pts_time:15.266667 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:B checksum:DAC04489 plane_checksum:[7AEF7AA2 6E0164EC 6E0164EC] mean:[16 128 128] stdev:[0.6 0.0 0.0]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 459 pts: 235008 pts_time:15.3    duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:B checksum:DAC04489 plane_checksum:[7AEF7AA2 6E0164EC 6E0164EC] mean:[16 128 128] stdev:[0.6 0.0 0.0]
# [Parsed_showinfo_0 @ 000001c0fd6ae400] n: 460 pts: 235520 pts_time:15.333333 duration:    512 duration_time:0.0333333 fmt:yuv420p cl:left sar:1/1 s:640x270 i:P iskey:0 type:P checksum:690B4446 plane_checksum:[62E27A5F 6E0164EC 6E0164EC] mean:[16 128 128] stdev:[0.6 0.0 0.0]
# Frame percentages: {'I': 4.3383947939262475, 'P': 58.13449023861171, 'B': 37.52711496746204}

# %%
import cv2
import matplotlib.pyplot as plt

# Load and display I-frame
i_frame_path = "C:/Users/91924/Desktop/MY WORKS/sem 7/image and video analytics/iframes/i_frames_001.png"
i_frame = cv2.imread(i_frame_path)
if i_frame is not None:
    i_frame_rgb = cv2.cvtColor(i_frame, cv2.COLOR_BGR2RGB)
    plt.figure(figsize=(10, 10))
    plt.imshow(i_frame_rgb)
    plt.title('I-Frame')
    plt.axis('off')
    plt.show()
else:
    print(f"Error: File not found at {i_frame_path}")

# Load and display P-frame
p_frame_path = "C:/Users/91924/Desktop/MY WORKS/sem 7/image and video analytics/pframe/p_frames_001.png"
p_frame = cv2.imread(p_frame_path)
if p_frame is not None:
    p_frame_rgb = cv2.cvtColor(p_frame, cv2.COLOR_BGR2RGB)
    plt.figure(figsize=(10, 10))
    plt.imshow(p_frame_rgb)
    plt.title('P-Frame')
    plt.axis('off')
    plt.show()
else:
    print(f"Error: File not found at {p_frame_path}")

# Load and display B-frame
b_frame_path = "C:/Users/91924/Desktop/MY WORKS/sem 7/image and video analytics/bframes/b_frames_001.png"
b_frame = cv2.imread(b_frame_path)
if b_frame is not None:
    b_frame_rgb = cv2.cvtColor(b_frame, cv2.COLOR_BGR2RGB)
    plt.figure(figsize=(10, 10))
    plt.imshow(b_frame_rgb)
    plt.title('B-Frame')
    plt.axis('off')
    plt.show()
else:
    print(f"Error: File not found at {b_frame_path}")

# %%
import os
from skimage import io
from skimage.metrics import structural_similarity as ssim

def get_file_size(file_path):
    """Returns the file size in bytes."""
    if os.path.exists(file_path):
        return os.path.getsize(file_path)
    else:
        print(f"Error: File not found at {file_path}")
        return None

def calculate_ssim(image_path1, image_path2, data_range):
    """Calculates the SSIM between two images."""
    image1 = io.imread(image_path1, as_gray=True)
    image2 = io.imread(image_path2, as_gray=True)
    ssim_index, _ = ssim(image1, image2, data_range=data_range, full=True)
    return ssim_index

# Paths
i_frame_path = "C:/Users/91924/Desktop/MY WORKS/sem 7/image and video analytics/iframes/i_frames_001.png"
p_frame_path = "C:/Users/91924/Desktop/MY WORKS/sem 7/image and video analytics/pframe/p_frames_001.png"
b_frame_path = "C:/Users/91924/Desktop/MY WORKS/sem 7/image and video analytics/bframes/b_frames_001.png"

# Getting sizes
i_frame_size = get_file_size(i_frame_path)
p_frame_size = get_file_size(p_frame_path)
b_frame_size = get_file_size(b_frame_path)

print(f"I-frame size: {i_frame_size / 1024:.2f} KB")
print(f"P-frame size: {p_frame_size / 1024:.2f} KB")
print(f"B-frame size: {b_frame_size / 1024:.2f} KB")

# Assuming 8-bit images
data_range = 255

# Calculating SSIM
ssim_p_vs_i = calculate_ssim(i_frame_path, p_frame_path, data_range)
ssim_b_vs_i = calculate_ssim(i_frame_path, b_frame_path, data_range)
ssim_b_vs_p = calculate_ssim(p_frame_path, b_frame_path, data_range)

print(f"SSIM between I-frame and P-frame: {ssim_p_vs_i:.4f}")
print(f"SSIM between I-frame and B-frame: {ssim_b_vs_i:.4f}")
print(f"SSIM between P-frame and B-frame: {ssim_b_vs_p:.4f}")
# Out:
# I-frame size: 2.84 KB
# P-frame size: 4.54 KB
# B-frame size: 27.58 KB
# SSIM between I-frame and P-frame: 0.9999
# SSIM between I-frame and B-frame: 0.8990
# SSIM between P-frame and B-frame: 0.9039

# %%
import os

# Function to get file size
def get_file_size(filepath):
    return os.path.getsize(filepath)

# Function to list all files in a directory
def list_files_in_directory(directory_path):
    return [os.path.join(directory_path, filename) for filename in os.listdir(directory_path) if os.path.isfile(os.path.join(directory_path, filename))]

# Function to calculate average size
def calculate_average_size(frame_paths):
    total_size = sum(get_file_size(path) for path in frame_paths)
    return total_size / len(frame_paths) if frame_paths else 0

# Paths to your frame directories
i_frame_dir = 'C:/Users/91924/Desktop/MY WORKS/sem 7/image and video analytics/iframes'
p_frame_dir = 'C:/Users/91924/Desktop/MY WORKS/sem 7/image and video analytics/pframe'
b_frame_dir = 'C:/Users/91924/Desktop/MY WORKS/sem 7/image and video analytics/bframes'

# List files in each directory
i_frame_paths = list_files_in_directory(i_frame_dir)
p_frame_paths = list_files_in_directory(p_frame_dir)
b_frame_paths = list_files_in_directory(b_frame_dir)

# Calculate average sizes
avg_i_frame_size = calculate_average_size(i_frame_paths)
avg_p_frame_size = calculate_average_size(p_frame_paths)
avg_b_frame_size = calculate_average_size(b_frame_paths)

# Print average sizes
print(f"Average I Frame Size: {avg_i_frame_size} bytes")
print(f"Average P Frame Size: {avg_p_frame_size} bytes")
print(f"Average B Frame Size: {avg_b_frame_size} bytes")
# Out:
# Average I Frame Size: 31601.1 bytes
# Average P Frame Size: 113192.69402985074 bytes
# Average B Frame Size: 127643.63005780347 bytes

# %%
import cv2
import os
frames_path = 'C:/Users/91924/Desktop/MY WORKS/sem 7/image and video analytics/iframes'
output_video_path = 'C:/Users/91924/Desktop/output_video.mp4'


frame_rate = 1 

# Get list of files in the directory and sort them
frames = sorted([f for f in os.listdir(frames_path) if f.endswith('.png')])

# Read the first frame to get width and height
first_frame = cv2.imread(os.path.join(frames_path, frames[0]))
height, width, _ = first_frame.shape

# Define the codec and create VideoWriter object
fourcc = cv2.VideoWriter_fourcc(*'mp4v')  
video_writer = cv2.VideoWriter(output_video_path, fourcc, frame_rate, (width, height))

# Write each frame to the video
for frame_file in frames:
    frame_path = os.path.join(frames_path, frame_file)
    frame = cv2.imread(frame_path)
    video_writer.write(frame)

# Release the VideoWriter object
video_writer.release()
